# %% [markdown]
# # BRAN2020 clim demo sandbox

# %% [markdown]
# Date: 7 March, 2024

# %% [markdown]
# Author = {"name": "Thomas Moore", "affiliation": "CSIRO", "email": "thomas.moore@csiro.au", "orcid": "0000-0003-3930-1946"}

# %% [markdown]
# ### BRAN2020 is on the order of 100TB of float data over nearly 9000 `netcdf` file assests in total.

# %% [markdown]
# #### required packages

# %%
import intake
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
#more plotting
import matplotlib.dates as mdates
#import seaborn as sns
from rechunker import rechunk
from streamjoy import stream
import streamjoy
import streamjoy.xarray

# %%
xr.__version__
# Out:
# '2024.3.0'

# %% [markdown]
# #### ignore warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### start a local Dask client

# %%
import dask
import distributed

with dask.config.set({"distributed.scheduler.worker-saturation": 1.0,
                      "distributed.nanny.pre-spawn-environ.MALLOC_TRIM_THRESHOLD_": 0,
                    "logging.distributed'": "error"}):
    client = distributed.Client()

# %% [markdown]
# # where are the zarr collections:

# %%
zarr_path = '/scratch/es60/ard/reanalysis/BRAN2020/ARD/'
temp_chunk4time_zarr = 'BRAN2020-daily-temp-chunk4time-v07022024.zarr'

# %%
temp_chunk4time = xr.open_zarr(zarr_path+temp_chunk4time_zarr,consolidated=True)

# %%
temp_chunk4time
# Out:
# <xarray.Dataset> Size: 12TB
# Dimensions:   (Time: 11138, st_ocean: 51, yt_ocean: 1500, xt_ocean: 3600)
# Coordinates:
#   * Time      (Time) datetime64[ns] 89kB 1993-01-01T12:00:00 ... 2023-06-30T1...
#   * st_ocean  (st_ocean) float64 408B 2.5 7.5 12.5 ... 3.603e+03 4.509e+03
#   * xt_ocean  (xt_ocean) float64 29kB 0.05 0.15 0.25 0.35 ... 359.8 359.9 360.0
#   * yt_ocean  (yt_ocean) float64 12kB -74.95 -74.85 -74.75 ... 74.75 74.85 74.95
# Data variables:
#     temp      (Time, st_ocean, yt_ocean, xt_ocean) float32 12TB dask.array<chunksize=(11138, 51, 100, 1), meta=np.ndarray>
# Attributes: (12/13)
#     NumFilesInSet:                   20
#     acknowledgement:                 BRAN is made freely available by CSIRO B...
#     catalogue_doi_url:               http://dx.doi.org/10.25914/6009627c7af03
#     grid_tile:                       N/A
#     grid_type:                       regular
#     intake_esm_attrs:_data_format_:  netcdf
#     ...                              ...
#     intake_esm_attrs:source:         BRAN2020
#     intake_esm_attrs:time_period:    daily
#     intake_esm_attrs:variable:       temp
#     intake_esm_dataset_key:          ocean.daily
#     intake_esm_vars:                 ['temp']
#     title:                           BRAN2020

# %%
# %%time
equator_over_time = temp_chunk4time.temp.sel({'yt_ocean':0},method='nearest')
# Out:
# CPU times: user 14 ms, sys: 3.65 ms, total: 17.6 ms
# Wall time: 16.1 ms

# %%
# %%time
equator_over_time = equator_over_time.compute()
# Out:
# CPU times: user 1min 13s, sys: 25.5 s, total: 1min 38s
# Wall time: 2min 36s

# %%
equator_over_time.streamjoy('/g/data/es60/users/thomas_moore/clim_demo_results/plots/equator_temp.mp4',max_frames=-1,dim='Time')
# Out:
# <Client: 'tcp://127.0.0.1:42051' processes=7 threads=28, memory=251.18 GiB>
# 2024-04-10 09:35:14,410 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:14,472 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:14,653 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:15,557 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:17,200 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:17,340 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:17,638 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:17,789 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:18,032 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:18,680 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:18,991 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:20,684 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:20,853 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:21,301 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:21,455 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:21,509 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:22,016 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:22,620 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:24,263 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:24,457 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:24,937 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:25,115 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:25,142 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:25,502 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:26,583 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:27,422 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:28,193 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:28,512 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:28,606 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:28,685 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:28,738 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:30,291 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:31,103 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:31,943 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:31,979 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:32,000 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:32,099 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:32,303 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:34,052 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:34,701 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:35,268 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:35,377 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:35,424 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:35,540 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:35,641 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:37,699 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:37,975 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:38,619 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:38,825 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:38,859 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:39,098 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:39,198 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:41,437 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:41,572 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:42,141 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:42,456 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:42,538 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:42,661 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:43,209 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:44,944 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:45,348 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:45,465 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:45,592 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:46,039 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:46,304 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:46,584 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:48,176 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:48,804 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:48,961 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:49,038 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:49,407 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:49,618 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:50,309 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:51,924 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:51,980 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:52,148 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:52,536 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:52,811 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:53,184 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:53,988 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:55,246 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:55,527 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:55,811 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:55,995 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:56,097 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:56,436 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:57,537 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:58,781 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:35:59,055 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:59,497 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:59,507 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:59,694 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:35:59,955 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:01,046 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:03,763 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:03,797 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:04,007 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:04,043 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:04,811 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:05,186 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:06,565 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:07,718 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:07,864 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:07,873 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:08,209 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:08,215 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:08,539 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:10,169 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:11,221 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:11,261 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:11,405 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:11,862 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:12,014 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:12,033 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:13,850 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:14,579 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:14,709 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:14,882 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:15,463 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:15,534 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:15,743 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:17,543 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:17,801 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:18,479 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:18,652 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:18,724 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:18,967 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:19,054 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:21,267 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:21,380 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:22,078 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:22,257 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:22,497 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:22,536 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:22,565 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:24,649 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:25,006 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:25,294 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:25,693 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:25,926 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:26,033 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:26,242 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:28,043 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:28,568 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:28,631 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:29,078 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:29,335 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:29,572 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:29,764 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:31,443 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:31,833 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:32,168 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:32,227 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:32,672 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:33,257 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:33,383 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:34,755 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:35,217 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:35,643 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:35,937 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:36,470 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:36,812 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:37,173 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:38,284 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:38,442 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:39,310 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:39,358 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:40,046 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:40,565 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:40,601 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:42,024 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:42,199 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:42,714 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:42,772 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:43,410 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:43,932 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:44,150 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:45,363 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:45,366 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:46,062 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:46,650 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:47,197 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:47,463 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:47,635 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:48,731 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:48,986 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:49,849 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:50,187 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:51,019 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:51,104 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:51,153 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:52,207 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:52,445 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:53,335 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:53,550 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:54,482 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:54,520 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:54,731 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:55,722 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:55,726 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:56,940 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:57,083 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:57,981 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:58,429 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:59,000 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:36:59,068 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:36:59,301 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:00,989 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:00,998 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:01,626 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:02,425 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:02,495 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:02,591 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:02,848 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:04,258 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:04,633 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:05,214 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:06,097 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:06,187 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:06,273 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:06,520 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:08,299 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:08,430 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:09,534 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:09,869 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:09,886 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:09,985 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:10,245 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:12,164 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:12,608 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:13,069 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:13,779 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:13,825 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:14,200 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:14,258 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:15,839 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:16,398 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:16,740 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:17,613 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:17,727 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:18,134 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:18,313 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:19,474 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:20,256 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:20,798 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:21,453 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:21,672 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:21,830 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:22,492 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:23,526 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:37:24,370 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-10 09:37:24,517 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
# ...
# 2024-04-10 09:42:49,222 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:49,969 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:50,666 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:50,696 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:42:52,252 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:53,704 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:54,156 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:42:57,325 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:58,355 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:58,709 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:42:58,965 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:00,597 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:02,056 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:02,248 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:05,430 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:06,311 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:07,179 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:07,722 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:08,641 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:10,606 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:10,620 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:13,567 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:14,477 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:15,537 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:16,156 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:17,271 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:18,642 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:19,189 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:21,688 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:22,800 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:23,759 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:24,729 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:25,052 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:27,558 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:27,582 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:30,201 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:31,300 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:32,358 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:33,202 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:33,734 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:35,572 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:35,787 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:38,816 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:40,166 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:41,402 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:41,567 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:42,544 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:44,448 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:44,511 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:47,711 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:48,688 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:49,914 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:50,271 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:50,981 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:52,983 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:53,051 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:57,125 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:57,810 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:58,785 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_streamjoy/lib/python3.10/site-packages/matplotlib/colors.py:743: RuntimeWarning: invalid value encountered in cast
#   xa = xa.astype(int)
# 2024-04-10 09:43:59,377 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-04-10 09:43:59,638 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# [SUCCESS] 09:46AM: Saved stream to /g/data/es60/users/thomas_moore/clim_demo_results/plots/equator_temp.mp4.
# <video src="/g/data/es60/users/thomas_moore/clim_demo_results/plots/equator_temp.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
# PosixPath('/g/data/es60/users/thomas_moore/clim_demo_results/plots/equator_temp.mp4')

# %%
_slice_.plot()

# %%
# %time
result = result.compute()

# %%
result.plot()

# %% [markdown]
# # ARD workflow

# %% [markdown]
# ### read paths from config file

# %% [markdown]
# #### [ you will need to specifiy your correct path for the `data-catalogue/config.ini` file ]

# %%
import configparser

# Create a ConfigParser object
config = configparser.ConfigParser()

# Read the config file
#########
#### you will need to specifiy your correct path the the `data-catalogue/config.ini` file 
#########
config.read('./code/BRAN2020-intake-catalog/config.ini')

# Get the value of a variable
catalog_path = config.get('paths', 'catalog_path')

# %%
catalog_path

# %%
BRAN2020_catalog = intake.open_esm_datastore(catalog_path+'BRAN2020.json',columns_with_iterables=['variable'])

# %%
BRAN2020_catalog

# %%
BRAN2020_catalog.unique()['source']

# %%
BRAN2020_catalog.unique()['domain']

# %%
BRAN2020_catalog.unique()['time_period']

# %%
var_list = BRAN2020_catalog.unique()['variable']
var_list.sort()
df = pd.DataFrame(var_list, columns=['BRAN2020 Variables'])
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df)

# %%
search = BRAN2020_catalog.search(variable=['mld'],time_period=['daily'])

# %%
search.unique()['variable']

# %%
search

# %%
search.df

# %% [markdown]
# ### Out of some 9000 files we now have narrowed down the just the 366 that have the information we need

# %% [markdown]
# #### We can now load all that data into a single 240GB "lazy" `xarray` object for further reduction and analysis

# %%
# %%time
xarray_open_kwargs = {"chunks": {"time": 1, "xt_ocean": 3600, "yt_ocean": 1500}}
DS=search.to_dask(xarray_open_kwargs=xarray_open_kwargs)

# %%
DS

# %%
DS.nbytes/1e9

# %% [markdown]
# ## ARD - write zarr & chunk & write zarr

# %%
BRAN2020_ard_path = '/scratch/es60/ard/reanalysis/BRAN2020/ARD/2D/'
ard_file_ID = 'BRAN2020-daily-mld-v04042024.zarr'

# %%
# %%time
DS.to_zarr(BRAN2020_ard_path+ard_file_ID,consolidated=True)
# ----- Client(threads_per_worker=1) -------
# CPU times: user 2min 26s, sys: 29.9 s, total: 2min 56s
# Wall time: 13min 1s
# ----- Client() -------
# CPU times: user 1min 53s, sys: 18.1 s, total: 2min 11s
# Wall time: 14min 3s

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/2D/finished_BRAN2020-mld-base-zarr.log

# %% [markdown]
# ## RELOAD in ARD collection

# %%
BRAN2020_daily_var = xr.open_zarr(BRAN2020_ard_path+ard_file_ID,consolidated=True)

# %%
BRAN2020_daily_var

# %% [markdown]
# ## CHUNK for time and WRITE zarr

# %% [markdown]
# ### "Consider either rechunking using `chunk()`, deleting or modifying `encoding['chunks']`"

# %%
def remove_zarr_encoding(DS):
    for var in DS:
        DS[var].encoding = {}

    for coord in DS.coords:
        DS[coord].encoding = {}
    return DS

# %%
ard_rcTime_file_ID = 'BRAN2020-daily-mld-chunk4time-v04042024.zarr'

# %%
BRAN2020_daily_var_rcTime =  BRAN2020_daily_var.chunk({'Time':-1,'xt_ocean':9,'yt_ocean':1500})
BRAN2020_daily_var_rcTime

# %%
BRAN2020_daily_var_rcTime = remove_zarr_encoding(BRAN2020_daily_var_rcTime)

# %%
# %%time
BRAN2020_daily_var_rcTime.to_zarr(BRAN2020_ard_path+ard_rcTime_file_ID,consolidated=True)

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/2D/finished_BRAN2020-mld-rechunk-zarr.log

# %% [markdown]
# # rechunker approach

# %%
input_ds = BRAN2020_daily_var
target_chunks = {'Time':-1,'xt_ocean':9,'yt_ocean':1500}
max_mem = "2GB"

target_store = BRAN2020_ard_path+ard_rcTime_file_ID
temp_store = "/scratch/es60/ard/rechunker_scratch/rechunker-tmp.zarr"

# need to remove the existing stores or it won't work
# !rm -rf /scratch/es60/ard/rechunker_scratch/rechunker-tmp.zarr

# rechunk directly from dataset this time
rechunk_plan = rechunk(
    input_ds, target_chunks, max_mem, target_store, temp_store=temp_store
)
rechunk_plan

# %%
# %%time
rechunk_plan.execute()

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/2D/finished_BRAN2020-mld-rechunker-zarr.log

# %%
zarr.consolidate_metadata(target_store)

# %% [markdown]
# ## end ARD workflow $\Uparrow$

# %% [markdown]
# # begin post-processing workflow $\Downarrow$

# %% [markdown]
# ## load in zarr collection

# %%
var_chunked_time = xr.open_zarr(BRAN2020_ard_path + ard_rcTime_file_ID,consolidated=True)
var_chunked_time

# %% [markdown]
# ## basic functions

# %%
def get_bran_monthly_climatologies(xr_object,time_coord_name = 'Time'):
    monthly_climatologies = xr_object.groupby(time_coord_name+'.month').mean(dim=time_coord_name,keep_attrs = True,method="cohorts", engine="flox")
    result = data.groupby('time').temperature.agg(['mean', 'sum'])
    
return result

# %% [markdown]
# # Climatology

# %%
temp_monthly_climatology = get_monthly_climatology(temp_chunked_time, time_coord_name = 'Time')
temp_monthly_climatology

# %%
temp_monthly_climatology_rc = temp_monthly_climatology.chunk({'st_ocean':10,'xt_ocean':3600,'month':1})

# %%
# %%time
temp_monthly_climatology = temp_monthly_climatology.compute()

# CPU times: user 32.1 s, sys: 17.9 s, total: 49.9 s
# Wall time: 2min 20s
#

# %% [raw]
# temp_monthly_climatology_slow = get_monthly_climatology(temp_chunked, time_coord_name = 'Time')
# temp_monthly_climatology_slow

# %% [raw]
# %%time
# temp_monthly_climatology_slow = temp_monthly_climatology_slow.compute()
# ## ----- Client() -------
# # CPU times: user 5min 13s, sys: 1min 9s, total: 6min 22s
# # Wall time: 39min 59s
# #

# %% [raw]
# temp_monthly_climatology_slow_no_flox = get_monthly_climatology(temp_chunked, time_coord_name = 'Time',flox=False)

# %% [raw]
# %%time
# temp_monthly_climatology_slow_no_flox = temp_monthly_climatology_slow_no_flox.compute()
# ## ----- Client() -------
# # CPU times: user 6min 49s, sys: 1min 28s, total: 8min 17s
# # Wall time: 51min 9s
# #

# %% [markdown]
# # Anomaly

# %%
temp_anomaly = get_monthly_anomaly(temp_chunked,temp_monthly_climatology_rc,time_coord_name='Time')

# %%
temp_anomaly

# %% [markdown]
# # define El Nino and La Nina using NCAR ONI data

# %%
ONI_DF = pd.read_csv('/g/data/xv83/users/tm4888/data/ENSO/NCAR_ONI.csv')
ONI_DF.set_index('datetime',inplace=True)
ONI_DF.index = pd.to_datetime(ONI_DF.index)
el_nino_threshold = 0.5
la_nina_threshold = -0.5
el_nino_threshold_months = ONI_DF["ONI"].ge(el_nino_threshold)
la_nina_threshold_months = ONI_DF["ONI"].le(la_nina_threshold) 
ONI_DF = pd.concat([ONI_DF, el_nino_threshold_months.rename('El Nino threshold')], axis=1)
ONI_DF = pd.concat([ONI_DF, la_nina_threshold_months.rename('La Nina threshold')], axis=1)
ONI_DF = pd.concat([ONI_DF, el_nino_threshold_months.diff().ne(0).cumsum().rename('El Nino event group ID')], axis=1)
ONI_DF = pd.concat([ONI_DF, la_nina_threshold_months.diff().ne(0).cumsum().rename('La Nina event group ID')], axis=1)

# %%
El_Nino_Series = ONI_DF.groupby('El Nino event group ID')['ONI'].filter(lambda x: len(x) >= 5,dropna=False).where(ONI_DF['El Nino threshold'] == True)
ONI_DF = pd.concat([ONI_DF, El_Nino_Series.rename('El Nino')], axis=1)
La_Nina_Series = ONI_DF.groupby('La Nina event group ID')['ONI'].filter(lambda x: len(x) >= 5,dropna=False).where(ONI_DF['La Nina threshold'] == True)
ONI_DF = pd.concat([ONI_DF, La_Nina_Series.rename('La Nina')], axis=1)
ONI_DF

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4), layout='constrained')
ax.plot(ONI_DF.index,ONI_DF['El Nino'])
ax.xaxis.set_major_locator(mdates.YearLocator(base=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
plt.title('ONI El Nino events') 
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4), layout='constrained')
ax.plot(ONI_DF.index,ONI_DF['La Nina'])
ax.xaxis.set_major_locator(mdates.YearLocator(base=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
plt.title('ONI La Nina events') 
plt.show()

# %% [markdown]
# ## heatmap

# %% [markdown]
# ### make table for average over certain region

# %%
# %%time
max_lat = 5.0
min_lat = -5.0
max_lon = 240
min_lon = 190
LatIndexer, LonIndexer = 'yt_ocean', 'xt_ocean'
SliceData = temp_anomaly.temp.isel(st_ocean=0).sel(**{LatIndexer: slice(min_lat, max_lat),
                        LonIndexer: slice(min_lon, max_lon)})
SliceData = SliceData.chunk({'Time':-1,'yt_ocean':-1,'xt_ocean':-1,})
# THIS CURRENTLY IGNORES GRID AREA CORRECTION 
spatial_mean_of_ONI_anomaly = SliceData.mean({'yt_ocean','xt_ocean'})
spatial_mean_of_ONI_anomaly = spatial_mean_of_ONI_anomaly.compute()

# %%
spatial_mean_of_ONI_anomaly.plot()

# %%
spatial_mean_of_ONI_anomaly_DF = spatial_mean_of_ONI_anomaly.to_dataframe()
spatial_mean_of_ONI_anomaly_DF['year'] = pd.DatetimeIndex(spatial_mean_of_ONI_anomaly_DF.index).year
spatial_mean_of_ONI_anomaly_DF

# %%
heatmap_data = spatial_mean_of_ONI_anomaly_DF.pivot_table(index='month', columns='year', values='temp')

# %%
heatmap_data

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(heatmap_data, cmap='RdBu_r', square=True,vmin=-2.5, vmax=2.5,linewidth=.5)
plt.title('Month by Year BRAN2020 anomalies in ONI (Nino3.4) region')
plt.show()

# %% [markdown]
# ## stacked heatmap plot

# %%
ONI_DF_BRANtime = ONI_DF['1993-01':'2022-12']

# %%
event_data_EN = ONI_DF_BRANtime.pivot_table(index='month', columns='year', values='El Nino',dropna=False).fillna('')
event_data_LN = ONI_DF_BRANtime.pivot_table(index='month', columns='year', values='La Nina',dropna=False).fillna('')

# %%
plt.figure(figsize=(20,8))
sns.heatmap(heatmap_data, annot=False,cmap='RdBu_r', square=True,vmin=-2.5, vmax=2.5,linewidth=.5)
sns.heatmap(heatmap_data, annot=event_data_LN, annot_kws={'va':'top'}, fmt="", cbar=False,cmap='RdBu_r', square=True,vmin=-2.5, vmax=2.5,linewidth=.5)
sns.heatmap(heatmap_data, annot=event_data_EN, annot_kws={'va':'bottom'}, fmt="", cbar=False,cmap='RdBu_r', square=True,vmin=-2.5, vmax=2.5,linewidth=.5)
plt.title('Month by Year BRAN2020 anomalies in ONI (Nino3.4) region\n ONI values shown for defined ENSO events')

# %% [markdown]
# #### count of events in BRAN2020 period
# El Nino = 8 events ( weak - strong ) as defined by ONI<br>
# La Nina = 10 events ( weak - strong ) as defined by ONI <br>
# El Nino months total = 70 = 19%
# La Nina months total = 119 = 33%
# Neutral months total = 171 = 48%

# %%
ONI_DF_BRANtime

# %% [markdown]
# # filter BRAN2020 data by ENSO

# %%
ONI_DF_BRANtime = ONI_DF['1993-01':'2022-12']
ONI_DF_BRANtime['El Nino LOGICAL'] = ONI_DF_BRANtime['El Nino'].notnull()
ONI_DF_BRANtime['La Nina LOGICAL'] = ONI_DF_BRANtime['La Nina'].notnull()
ONI_DF_BRANtime

# %%
El_Nino_mask = ONI_DF_BRANtime['El Nino LOGICAL']
El_Nino_mask = El_Nino_mask.to_xarray()
El_Nino_mask = El_Nino_mask.rename({'datetime':'Time'})
sync_Time = temp_chunked_time.Time
El_Nino_mask['Time'] = sync_Time

# %%
La_Nina_mask = ONI_DF_BRANtime['La Nina LOGICAL']
La_Nina_mask = La_Nina_mask.to_xarray()
La_Nina_mask = La_Nina_mask.rename({'datetime':'Time'})
sync_Time = temp_chunked_time.Time
La_Nina_mask['Time'] = sync_Time

# %%
ONI_DF_BRANtime['Neutral LOGICAL'] = (ONI_DF_BRANtime['El Nino LOGICAL'] == False) & (ONI_DF_BRANtime['La Nina LOGICAL'] == False)

# %%
ONI_DF_BRANtime['El Nino LOGICAL'].sum()

# %%
ONI_DF_BRANtime['La Nina LOGICAL'].sum()

# %%
ONI_DF_BRANtime['Neutral LOGICAL'].sum()

# %% [markdown]
# # Test if they add to 360

# %%
ONI_DF_BRANtime['El Nino LOGICAL'].sum() + ONI_DF_BRANtime['La Nina LOGICAL'].sum()+ONI_DF_BRANtime['Neutral LOGICAL'].sum() == 360

# %%
ONI_DF_BRANtime

# %%
El_Nino_BRAN2020_temp = temp_chunked_time.temp.where(El_Nino_mask)
La_Nina_BRAN2020_temp = temp_chunked_time.temp.where(La_Nina_mask)

# %%
# %%time
El_Nino_SST_mean = El_Nino_BRAN2020_temp.isel(st_ocean=0).mean('Time').compute()
La_Nina_SST_mean = La_Nina_BRAN2020_temp.isel(st_ocean=0).mean('Time').compute()

# %%
plt.figure(figsize=(16,8))
(El_Nino_SST_mean-La_Nina_SST_mean).plot()
plt.title('Mean monthly BRAN2020 SST for El Nino - La Nina events')

# %% [markdown]
# ## El Nino "climatology"

# %%
# %%time
El_Nino_temp_monthly_climatology = get_monthly_climatology(El_Nino_BRAN2020_temp, time_coord_name = 'Time')
El_Nino_temp_monthly_climatology_rc = El_Nino_temp_monthly_climatology.chunk({'st_ocean':10,'xt_ocean':3600,'month':1})
El_Nino_temp_monthly_climatology = El_Nino_temp_monthly_climatology.compute()

# %% [markdown]
# ## La Nina "climatology"

# %%
# %%time
La_Nina_temp_monthly_climatology = get_monthly_climatology(La_Nina_BRAN2020_temp, time_coord_name = 'Time')
La_Nina_temp_monthly_climatology_rc = La_Nina_temp_monthly_climatology.chunk({'st_ocean':10,'xt_ocean':3600,'month':1})
La_Nina_temp_monthly_climatology = La_Nina_temp_monthly_climatology.compute()

# %%
El_Nino_temp_monthly_climatology

# %%
diff_EN_LN_climatology = El_Nino_temp_monthly_climatology - La_Nina_temp_monthly_climatology

# %%
diff_EN_LN_climatology

# %%
# %%time
max_lat = 5.0
min_lat = -5.0
max_lon = 240
min_lon = 190
LatIndexer, LonIndexer = 'yt_ocean', 'xt_ocean'
SliceData = diff_EN_LN_climatology.isel(st_ocean=0).sel(**{LatIndexer: slice(min_lat, max_lat),
                        LonIndexer: slice(min_lon, max_lon)})
SliceData = SliceData.chunk({'month':-1,'yt_ocean':-1,'xt_ocean':-1,})
# THIS CURRENTLY IGNORES GRID AREA CORRECTION 
spatial_mean_diff_EN_LN = SliceData.mean({'yt_ocean','xt_ocean'})
spatial_mean_diff_EN_LN = spatial_mean_diff_EN_LN.compute()

# %%
spatial_mean_diff_EN_LN.plot(ylim=[0,3])

# %%
# %%time
max_lat = 5.0
min_lat = -5.0
max_lon = 240
min_lon = 190
LatIndexer, LonIndexer = 'yt_ocean', 'xt_ocean'
SliceData = El_Nino_temp_monthly_climatology.isel(st_ocean=0).sel(**{LatIndexer: slice(min_lat, max_lat),
                        LonIndexer: slice(min_lon, max_lon)})
SliceData = SliceData.chunk({'month':-1,'yt_ocean':-1,'xt_ocean':-1,})
# THIS CURRENTLY IGNORES GRID AREA CORRECTION 
spatial_mean_EN = SliceData.mean({'yt_ocean','xt_ocean'})
spatial_mean_EN = spatial_mean_EN.compute()
spatial_mean_EN.plot()

# %% [markdown]
# # Mean, Median, Max , Min

# %%
El_Nino_mean = El_Nino_BRAN2020_temp.mean('Time')
El_Nino_median = El_Nino_BRAN2020_temp.median('Time')
El_Nino_max = El_Nino_BRAN2020_temp.max('Time')
El_Nino_min = El_Nino_BRAN2020_temp.min('Time')
El_Nino_std = El_Nino_BRAN2020_temp.std('Time')
El_Nino_quant = El_Nino_BRAN2020_temp.quantile([0.05,0.95],skipna=True,dim='Time')

# %%
# %%time
El_Nino_quant.isel(quantile=0).isel(st_ocean=0).plot(robust=True,vmin=-1,vmax=35)

# %%
# %%time
El_Nino_quant.isel(quantile=1).isel(st_ocean=0).plot(robust=True,vmin=-1,vmax=35)

# %%
def get_slice(xr_object)
    max_lat = 5.0
    min_lat = -5.0
    max_lon = 240
    min_lon = 190
    LatIndexer, LonIndexer = 'yt_ocean', 'xt_ocean'
    SliceData = xr_object.sel(**{LatIndexer: slice(min_lat, max_lat),
                        LonIndexer: slice(min_lon, max_lon)})

# %%
El_Nino_min.isel(st_ocean=0).plot(robust=True,vmin=-1,vmax=35)

# %%
El_Nino_max.isel(st_ocean=0).plot(robust=True,vmin=-1,vmax=35)

# %%
diff = El_Nino_max.isel(st_ocean=0) - El_Nino_min.isel(st_ocean=0) 
diff.plot(robust=True)

# %%
El_Nino_std.isel(st_ocean=0).plot(robust=True)

# %% [markdown]
# # The End

# %%
client.shutdown()

# %% [markdown]
# ## Plot current vectors for August

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import matplotlib.ticker as ticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy
from matplotlib import mlab, cm, gridspec
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
# %matplotlib inline

# %%
# %%time
# Define the u and v components of the currents
time_choice = 8
u = clim_uv.u.sel(month=time_choice)
v = clim_uv.v.sel(month=time_choice)
speed = np.sqrt(u**2 + v**2)

# %%
#plot model data
transform = ccrs.PlateCarree()
cmap = 'Spectral_r'
cbar_label='current speed'
plot_data = speed

###
fig = plt.figure(num=None, figsize=(8, 6), dpi=300, facecolor='w', edgecolor='k')
ax = plt.subplot(projection=ccrs.PlateCarree(180))
ax.set_extent([142,160, -25, -10], ccrs.PlateCarree())
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '50m', edgecolor='face', facecolor='white'))
ax.coastlines('50m',linewidth=0.5,edgecolor='grey')
plot_data.plot(transform=transform,cmap=cmap,cbar_kwargs={'label': cbar_label,'shrink':0.5},robust=True)

#plot u/v vectors
# Define the x and y coordinates
x = clim_uv.xu_ocean
y = clim_uv.yu_ocean
ax.quiver(x.values,y.values,u.values,v.values,transform=transform, units='x', width=0.01, scale=0.7, headwidth=2,alpha=0.2)
ax.set_title('BRAN2020 1993-2022\ncurrent speed \n August Climatology')
