# %%
import xarray as xr
import numpy as np
import pandas as pd
from flox.xarray import xarray_reduce
import gc

# %%
import dask
import distributed

with dask.config.set({"distributed.scheduler.worker-saturation": 1.0,
                      "distributed.nanny.pre-spawn-environ.MALLOC_TRIM_THRESHOLD_": 0}):
    client = distributed.Client()

# %%
ds = xr.tutorial.open_dataset('air_temperature')

# %% [markdown]
# # make minute data

# %%
finer_times = pd.date_range(start=ds.time[0].values, end=ds.time[-1].values, freq='min')

# %%
finer_times
# Out:
# DatetimeIndex(['2013-01-01 00:00:00', '2013-01-01 00:01:00',
#                '2013-01-01 00:02:00', '2013-01-01 00:03:00',
#                '2013-01-01 00:04:00', '2013-01-01 00:05:00',
#                '2013-01-01 00:06:00', '2013-01-01 00:07:00',
#                '2013-01-01 00:08:00', '2013-01-01 00:09:00',
#                ...
#                '2014-12-31 17:51:00', '2014-12-31 17:52:00',
#                '2014-12-31 17:53:00', '2014-12-31 17:54:00',
#                '2014-12-31 17:55:00', '2014-12-31 17:56:00',
#                '2014-12-31 17:57:00', '2014-12-31 17:58:00',
#                '2014-12-31 17:59:00', '2014-12-31 18:00:00'],
#               dtype='datetime64[ns]', length=1050841, freq='min')

# %%
finer_ds = ds.interp(time=finer_times, method='linear')

# %%
finer_ds.nbytes/1e9
# Out:
# 11.14732164

# %% [markdown]
# # coarsen to 3 minute data

# %%
coarsened_ds = finer_ds.coarsen(time=3, boundary='trim').mean()
coarsened_ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 350280, lat: 25, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 3MB 2013-01-01T00:01:00 ... 2014-12-31T17:...
# Data variables:
#     air      (time, lat, lon) float64 4GB 241.2 242.5 243.5 ... 296.2 295.7
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
coarsened_ds.nbytes/1e9
# Out:
# 3.715770552

# %%
data = coarsened_ds

# %% [markdown]
# # chunked

# %%
ds_dask = coarsened_ds.chunk({'lon': 27, 'lat': 12,'time':10000})
ds_dask
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 350280, lat: 25, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 3MB 2013-01-01T00:01:00 ... 2014-12-31T17:...
# Data variables:
#     air      (time, lat, lon) float64 4GB dask.array<chunksize=(10000, 12, 27), meta=np.ndarray>
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
# %%time
! rm /Users/moo270/data/test.nc
# Specify chunk sizes in the encoding dictionary
encoding = {'air': {'chunksizes': (10000, 12, 27)}}

ds_dask.to_netcdf('/Users/moo270/data/test.nc',encoding=encoding)
# Out:
# /Users/moo270/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/distributed/client.py:3157: UserWarning: Sending large graph of size 3.46 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# CPU times: user 3.37 s, sys: 3.09 s, total: 6.46 s
# Wall time: 9.27 s

# %%
data = xr.open_mfdataset('/Users/moo270/data/test.nc')
data
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 350280, lat: 25, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 3MB 2013-01-01T00:01:00 ... 2014-12-31T17:...
# Data variables:
#     air      (time, lat, lon) float64 4GB dask.array<chunksize=(10000, 12, 27), meta=np.ndarray>
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [raw]
# del result_cohort['air']
# del result_cohort
# gc.collect()

# %%
# %%time
result_cohort = xarray_reduce(
    data,
    'time.month',
    func="mean",
    method="cohorts",
).compute()
result_cohort.air.mean(['lat','lon']).plot()

# %%
# %%time
result_map = xarray_reduce(
    data,
    'time.month',
    func="mean",
    method="map-reduce",
).compute()
result_map.air.mean(['lat','lon']).plot()

# %%
# %%time
result = data.groupby('time.month').mean('time')
result.air.mean(['lat','lon']).plot()

# %%
# %%time
method = 'map-reduce'
var_string = list(data.data_vars.keys())[0]
merged_ds = xr.merge([xarray_reduce(data,'time.month',func="nanmean",method=method).rename({var_string:'mean_'+var_string}),
                      xarray_reduce(data,'time.month',func="min",method=method).rename({var_string:'min_'+var_string}),
                      xarray_reduce(data,'time.month',func="max",method=method).rename({var_string:'max_'+var_string}),
                      xarray_reduce(data,'time.month',func="nanstd",method=method).rename({var_string:'std_'+var_string}),
                      xarray_reduce(data,'time.month',func="nanmedian",method='blockwise').rename({var_string:'median_'+var_string})
                                    ])
merged_ds = merged_ds.compute()
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# File <timed exec>:7
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/flox/xarray.py:441, in xarray_reduce(obj, func, expected_groups, isbin, sort, dim, fill_value, dtype, method, engine, keep_attrs, skipna, min_count, reindex, *by, **finalize_kwargs)
#     438 output_sizes = group_sizes
#     439 output_sizes.update({dim.name: dim.size for dim in newdims if dim.size != 0})
# --> 441 actual = xr.apply_ufunc(
#     442     wrapper,
#     443     ds_broad.drop_vars(tuple(missing_dim)).transpose(..., *grouper_dims),
#     444     *by_da,
#     445     input_core_dims=input_core_dims,
#     446     # for xarray's test_groupby_duplicate_coordinate_labels
#     447     exclude_dims=set(dim_tuple),
#     448     output_core_dims=[output_core_dims],
#     449     dask="allowed",
#     450     dask_gufunc_kwargs=dict(
#     451         output_sizes=output_sizes, output_dtypes=[dtype] if dtype is not None else None
#     452     ),
#     453     keep_attrs=keep_attrs,
#     454     kwargs={
#     455         "func": func,
#     456         "axis": axis,
#     457         "sort": sort,
#     458         "fill_value": fill_value,
#     459         "method": method,
#     460         "min_count": min_count,
#     461         "skipna": skipna,
#     462         "engine": engine,
#     463         "reindex": reindex,
#     464         "expected_groups": tuple(expected_groups_valid_list),
#     465         "isbin": isbins,
#     466         "finalize_kwargs": finalize_kwargs,
#     467         "dtype": dtype,
#     468         "core_dims": input_core_dims,
#     469     },
#     470 )
#     472 # restore non-dim coord variables without the core dimension
#     473 # TODO: shouldn't apply_ufunc handle this?
#     474 for var in set(ds_broad._coord_names) - set(ds_broad._indexes) - set(ds_broad.dims):
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/xarray/core/computation.py:1257, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1255 # feed datasets apply_variable_ufunc through apply_dataset_vfunc
#    1256 elif any(is_dict_like(a) for a in args):
# -> 1257     return apply_dataset_vfunc(
#    1258         variables_vfunc,
#    1259         *args,
#    1260         signature=signature,
#    1261         join=join,
#    1262         exclude_dims=exclude_dims,
#    1263         dataset_join=dataset_join,
#    1264         fill_value=dataset_fill_value,
#    1265         keep_attrs=keep_attrs,
#    1266         on_missing_core_dim=on_missing_core_dim,
#    1267     )
#    1268 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1269 elif any(isinstance(a, DataArray) for a in args):
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/xarray/core/computation.py:532, in apply_dataset_vfunc(func, signature, join, dataset_join, fill_value, exclude_dims, keep_attrs, on_missing_core_dim, *args)
#     527 list_of_coords, list_of_indexes = build_output_coords_and_indexes(
#     528     args, signature, exclude_dims, combine_attrs=keep_attrs
#     529 )
#     530 args = tuple(getattr(arg, "data_vars", arg) for arg in args)
# --> 532 result_vars = apply_dict_of_variables_vfunc(
#     533     func,
#     534     *args,
#     535     signature=signature,
#     536     join=dataset_join,
#     537     fill_value=fill_value,
#     538     on_missing_core_dim=on_missing_core_dim,
#     539 )
#     541 out: Dataset | tuple[Dataset, ...]
#     542 if signature.num_outputs > 1:
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/xarray/core/computation.py:456, in apply_dict_of_variables_vfunc(func, signature, join, fill_value, on_missing_core_dim, *args)
#     454 core_dim_present = _check_core_dims(signature, variable_args, name)
#     455 if core_dim_present is True:
# --> 456     result_vars[name] = func(*variable_args)
#     457 else:
#     458     if on_missing_core_dim == "raise":
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/xarray/core/computation.py:825, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     820     if vectorize:
#     821         func = _vectorize(
#     822             func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     823         )
# --> 825 result_data = func(*input_data)
#     827 if signature.num_outputs == 1:
#     828     result_data = (result_data,)
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/flox/xarray.py:391, in xarray_reduce.<locals>.wrapper(array, func, skipna, core_dims, *by, **kwargs)
#     388         offset = array.min()
#     389         array = datetime_to_numeric(array, offset, datetime_unit="us")
# --> 391 result, *groups = groupby_reduce(array, *by, func=func, **kwargs)
#     393 # Transpose the new quantile dimension to the end. This is ugly.
#     394 # but new core dimensions are expected at the end :/
#     395 # but groupby_reduce inserts them at the beginning
#     396 if func in ["quantile", "nanquantile"]:
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/flox/core.py:2375, in groupby_reduce(array, func, expected_groups, sort, isbin, axis, fill_value, dtype, min_count, method, engine, reindex, finalize_kwargs, *by)
#    2369             groups = (groups[0][sorted_idx],)
#    2371 if factorize_early:
#    2372     # nan group labels are factorized to -1, and preserved
#    2373     # now we get rid of them by reindexing
#    2374     # This also handles bins with no data
# -> 2375     result = reindex_(result, from_=groups[0], to=expected_, fill_value=fill_value).reshape(
#    2376         result.shape[:-1] + grp_shape
#    2377     )
#    2378     groups = final_groups
#    2380 if is_bool_array and (_is_minmax_reduction(func) or _is_first_last_reduction(func)):
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/flox/core.py:596, in reindex_(array, from_, to, fill_value, axis, promote)
#     591 if from_.dtype.kind == "O" and isinstance(from_[0], tuple):
#     592     raise NotImplementedError(
#     593         "Currently does not support reindexing with object arrays of tuples. "
#     594         "These occur when grouping by multi-indexed variables in xarray."
#     595     )
# --> 596 idx = from_.get_indexer(to)
#     597 indexer = [slice(None, None)] * array.ndim
#     598 indexer[axis] = idx
#
# File ~/mambaforge/envs/pangeo_streamjoy/lib/python3.12/site-packages/pandas/core/indexes/base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# %%time
var_string = list(data.data_vars.keys())[0]
merged_ds = xr.merge([data.groupby('time.month').mean(dim='time',skipna=True).rename({var_string:'mean_'+var_string}),
                      data.groupby('time.month').min(dim='time',skipna=True).rename({var_string:'min_'+var_string}),
                      data.groupby('time.month').max(dim='time',skipna=True).rename({var_string:'max_'+var_string}),
                      data.groupby('time.month').std(dim='time',skipna=True).rename({var_string:'std_'+var_string}),
                      data.groupby('time.month').median(dim='time',skipna=True).rename({var_string:'median_'+var_string})
                                    ])
merged_ds = merged_ds.compute()
# Out:
# CPU times: user 3.95 s, sys: 915 ms, total: 4.86 s
# Wall time: 11.4 s

# %%
var_string = list(ds.data_vars.keys())[0]
result_DS = xr.merge([ds.groupby('time.month').mean(dim='time',engine='flox',method='cohorts').rename({var_string:'mean_'+var_string}),
                      ds.groupby('time.month').min(dim='time',engine='flox',method='cohorts').rename({var_string:'min_'+var_string}),
                      ds.groupby('time.month').max(dim='time',engine='flox',method='cohorts').rename({var_string:'max_'+var_string}),
                      ds.groupby('time.month').std(dim='time',engine='flox',method='cohorts').rename({var_string:'std_'+var_string}),
                      ds.groupby('time.month').median(dim='time').rename({var_string:'median_'+var_string})
])
result_DS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 var_string = list(ds.data_vars.keys())[0]
#       2 result_DS = xr.merge([ds.groupby('time.month').mean(dim='time',engine='flox',method='cohorts').rename({var_string:'mean_'+var_string}),
#       3                       ds.groupby('time.month').min(dim='time',engine='flox',method='cohorts').rename({var_string:'min_'+var_string}),
#       4                       ds.groupby('time.month').max(dim='time',engine='flox',method='cohorts').rename({var_string:'max_'+var_string}),
#       5                       ds.groupby('time.month').std(dim='time',engine='flox',method='cohorts').rename({var_string:'std_'+var_string}),
#       6                       ds.groupby('time.month').median(dim='time').rename({var_string:'median_'+var_string})
#       7 ])
#       8 result_DS
#
# NameError: name 'ds' is not defined

# %%
var_string = list(ds.data_vars.keys())[0]
quant = ds.groupby('time.month').quantile([0.05,0.95],skipna=False,dim='time')
quant

# %%
quant_ds = xr.merge([quant.isel(quantile=0).reset_coords(drop=True).rename({var_string:'quantile_05_'+var_string}),quant.isel(quantile=1).reset_coords(drop=True).rename({var_string:'quantile_95_'+var_string})])
quant_ds

# %%
result_DS = xr.merge([result_DS,quant_ds])
result_DS
