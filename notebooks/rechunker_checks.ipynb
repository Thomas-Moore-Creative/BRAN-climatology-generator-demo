# %% [markdown]
# # rechunker checks

# %%
Author_dict = {"name": "Thomas Moore", 
               "affiliation": "CSIRO", 
               "email": "thomas.moore@csiro.au",
               "orchid_ID":'https://orcid.org/0000-0003-3930-1946'}

# %%
import intake
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

from dask.distributed import Client, LocalCluster
import dask
import datetime
import zarr

from rechunker import rechunk

import gc
import sys
import subprocess
from tabulate import tabulate
import os
import glob

# %% [markdown]
# # my functions

# %%
# Append the directory of the module to sys.path - import functions
sys.path.append('/g/data/es60/users/thomas_moore/code/Climatology-generator-demo/src/')
import bran2020_demo_functions as my_tools
from bran2020_demo_functions import keep_only_selected_vars, load_rechunker_config, print_chunks, rechunk_each_st_ocean, remove_zarr_encoding, version_table, concatinate_st_ocean_zarrs

# %%
version_table(packages = ['rechunker','zarr'])
# Out:
# +-----------+-----------+-----------+-----------+------------+-----------+
# | Package   | Version   | Package   | Version   | Package    | Version   |
# +===========+===========+===========+===========+============+===========+
# | rechunker | 0.5.2     | dask      | 2024.4.0  | flox       | 0.9.6     |
# +-----------+-----------+-----------+-----------+------------+-----------+
# | zarr      | 2.17.1    | scipy     | 1.12.0    | bottleneck | 1.3.8     |
# +-----------+-----------+-----------+-----------+------------+-----------+
# | numpy     | 1.26.4    | numba     | 0.59.1    |            |           |
# +-----------+-----------+-----------+-----------+------------+-----------+
# | xarray    | 2024.3.0  | numbagg   | 0.8.1     |            |           |
# +-----------+-----------+-----------+-----------+------------+-----------+

# %% [markdown]
# # cluster

# %%
#cluster=LocalCluster(n_workers=28,processes=True)#,threads_per_worker=1)
#cluster=LocalCluster()
#cluster=LocalCluster(n_workers=32,threads_per_worker=1,memory_limit='85GB')
cluster=LocalCluster(n_workers=28,threads_per_worker=1,processes=True)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:45683' processes=28 threads=28, memory=251.18 GiB>

# %%
BRAN2020_ard_path = '/scratch/es60/ard/reanalysis/BRAN2020/ARD/'
files = glob.glob(BRAN2020_ard_path+'*.zarr')
sorted_files = sorted(files, key=os.path.getctime)
sorted_files
# Out:
# ['/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-temp-v14032024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-v-v04042024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-u-v04042024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-mld-v04042024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-salt-v03042024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-eta_t-chunk4time-v14032024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-eta_t-v14032024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-temp-chunk4time-v07022024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-mld-chunk4time-v04042024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-daily-mld-chunk4month_clim-22042023.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/salt-chunk1-5-1500-3600-v07052024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-salt-chunks_Time1.st_ocean51.xt_ocean3600.yt_ocean1500.v08052024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/float32.BRAN2020-salt-chunks_Time1.st_ocean51.xt_ocean3600.yt_ocean1500.v08052024.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-temp-chunks_Time1.st_ocean51.xt_ocean3600.yt_ocean1500.2024.05.12.19.11.26.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-u-chunks_Time1.st_ocean51.xu_ocean3600.yu_ocean1500.2024.05.14.14.45.09.zarr',
#  '/scratch/es60/ard/reanalysis/BRAN2020/ARD/BRAN2020-v-chunks_Time1.st_ocean51.xu_ocean3600.yu_ocean1500.2024.05.15.11.42.18.zarr']

# %%
i=10
file = sorted_files[i]
sorted_files[i]
# Out:
# '/scratch/es60/ard/reanalysis/BRAN2020/ARD/salt-chunk1-5-1500-3600-v07052024.zarr'

# %%
ds = xr.open_zarr(file,consolidated=True)

# %%
ds.st_ocean.values
# Out:
# array([2.50000000e+00, 7.50000000e+00, 1.25000000e+01, 1.75153904e+01,
#        2.26670208e+01, 2.81693802e+01, 3.42180061e+01, 4.09549751e+01,
#        4.84549751e+01, 5.67180061e+01, 6.56693802e+01, 7.51670227e+01,
#        8.50153885e+01, 9.50000000e+01, 1.05000000e+02, 1.15000000e+02,
#        1.25000000e+02, 1.35000000e+02, 1.45000000e+02, 1.55000000e+02,
#        1.65000000e+02, 1.75000000e+02, 1.85000000e+02, 1.95000000e+02,
#        2.05189896e+02, 2.17054489e+02, 2.33194321e+02, 2.55884232e+02,
#        2.86608978e+02, 3.25884216e+02, 3.73194336e+02, 4.27054474e+02,
#        4.85189911e+02, 5.45511108e+02, 6.10415649e+02, 6.85926758e+02,
#        7.75926758e+02, 8.80415649e+02, 9.95511108e+02, 1.11531335e+03,
#        1.23835388e+03, 1.36815747e+03, 1.50773389e+03, 1.65815747e+03,
#        1.81835388e+03, 1.98531335e+03, 2.16518018e+03, 2.43110107e+03,
#        2.89484180e+03, 3.60310107e+03, 4.50918018e+03])

# %%
ds
# Out:
# <xarray.Dataset> Size: 12TB
# Dimensions:   (Time: 11322, st_ocean: 51, yt_ocean: 1500, xt_ocean: 3600)
# Coordinates:
#   * Time      (Time) datetime64[ns] 91kB 1993-01-01T12:00:00 ... 2023-12-31T1...
#   * st_ocean  (st_ocean) float64 408B 2.5 7.5 12.5 ... 3.603e+03 4.509e+03
#   * xt_ocean  (xt_ocean) float64 29kB 0.05 0.15 0.25 0.35 ... 359.8 359.9 360.0
#   * yt_ocean  (yt_ocean) float64 12kB -74.95 -74.85 -74.75 ... 74.75 74.85 74.95
# Data variables:
#     salt      (Time, st_ocean, yt_ocean, xt_ocean) float32 12TB dask.array<chunksize=(1, 5, 1500, 3600), meta=np.ndarray>
# Attributes:
#     NCO:                netCDF Operators version 4.9.2 (Homepage = http://nco...
#     NumFilesInSet:      20
#     acknowledgement:    BRAN is made freely available by CSIRO Bluelink and i...
#     catalogue_doi_url:  http://dx.doi.org/10.25914/6009627c7af03
#     filename:           TMP/ocean_ofam_1993_01_01.nc.0000
#     grid_tile:          N/A
#     grid_type:          regular
#     history:            Mon May 18 20:12:35 2020: ncrcat -4 --dfl_lvl 1 --cnk...
#     title:              BRAN2020

# %%
ds.st_ocean.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ds.st_ocean.values
#
# File /g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/xarray/core/common.py:285, in AttrAccessMixin.__getattr__(self, name)
#     283         with suppress(KeyError):
#     284             return source[name]
# --> 285 raise AttributeError(
#     286     f"{type(self).__name__!r} object has no attribute {name!r}"
#     287 )
#
# AttributeError: 'Dataset' object has no attribute 'st_ocean'

# %%
sorted_salt = ds.sortby('st_ocean')

# %%
sorted_salt
# Out:
# <xarray.Dataset> Size: 12TB
# Dimensions:   (Time: 11322, st_ocean: 51, yt_ocean: 1500, xt_ocean: 3600)
# Coordinates:
#   * Time      (Time) datetime64[ns] 91kB 1993-01-01T12:00:00 ... 2023-12-31T1...
#   * st_ocean  (st_ocean) float64 408B 2.5 7.5 12.5 ... 3.603e+03 4.509e+03
#   * xt_ocean  (xt_ocean) float64 29kB 0.05 0.15 0.25 0.35 ... 359.8 359.9 360.0
#   * yt_ocean  (yt_ocean) float64 12kB -74.95 -74.85 -74.75 ... 74.75 74.85 74.95
# Data variables:
#     salt      (st_ocean, Time, yt_ocean, xt_ocean) float32 12TB dask.array<chunksize=(1, 11322, 120, 120), meta=np.ndarray>
# Attributes:
#     NCO:                netCDF Operators version 4.9.2 (Homepage = http://nco...
#     NumFilesInSet:      20
#     acknowledgement:    BRAN is made freely available by CSIRO Bluelink and i...
#     catalogue_doi_url:  http://dx.doi.org/10.25914/6009627c7af03
#     filename:           TMP/ocean_ofam_1993_01_01.nc.0000
#     grid_tile:          N/A
#     grid_type:          regular
#     history:            Mon May 18 20:12:35 2020: ncrcat -4 --dfl_lvl 1 --cnk...
#     title:              BRAN2020

# %%
ds.isel({'Time':0,'st_ocean':0}).mean().compute()
# Out:
# <xarray.Dataset> Size: 20B
# Dimensions:   ()
# Coordinates:
#     Time      datetime64[ns] 8B 1993-01-01T12:00:00
#     st_ocean  float64 8B 115.0
# Data variables:
#     salt      float32 4B 34.9

# %%
sorted_salt.isel({'Time':0,'st_ocean':0}).mean().compute()
# Out:
# <xarray.Dataset> Size: 20B
# Dimensions:   ()
# Coordinates:
#     Time      datetime64[ns] 8B 1993-01-01T12:00:00
#     st_ocean  float64 8B 2.5
# Data variables:
#     salt      float32 4B 34.47
# 2024-05-17 12:45:47,924 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,925 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,926 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,926 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-05-17 12:45:47,926 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,930 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,930 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,932 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = gen.convert_yielded(ret)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/functools.py", line 889, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/functools.py", line 832, in dispatch
#     impl = dispatch_cache[cls]
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/weakref.py", line 415, in __getitem__
#     def __getitem__(self, key):
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,946 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-05-17 12:45:47,946 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-05-17 12:45:47,946 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-05-17 12:45:47,947 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2024-05-17 12:45:47,948 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/nanny.py", line 1022, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = gen.convert_yielded(ret)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/functools.py", line 889, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/tornado/gen.py", line 882, in convert_yielded
#     return _wrap_awaitable(yielded)  # type: ignore
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/site-packages/tornado/gen.py", line 848, in _wrap_awaitable
#     fut = asyncio.ensure_future(awaitable)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/tasks.py", line 615, in ensure_future
#     return _ensure_future(coro_or_future, loop=loop)
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/tasks.py", line 619, in _ensure_future
#     if futures.isfuture(coro_or_future):
#   File "/g/data/es60/users/thomas_moore/miniconda3/envs/pangeo_bran2020_demo/lib/python3.10/asyncio/base_futures.py", line 21, in isfuture
#     return (hasattr(obj.__class__, '_asyncio_future_blocking') and
# KeyboardInterrupt
# sys:1: RuntimeWarning: coroutine 'PeriodicCallback._run' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# sys:1: RuntimeWarning: coroutine 'PeriodicCallback._run' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
bad_salt

# %%
BRAN2020_ard_path = '/scratch/es60/ard/reanalysis/BRAN2020/ARD/'
files = glob.glob(BRAN2020_ard_path+'*.zarr')
sorted_files = sorted(files, key=os.path.getctime)
sorted_files

# %%
xr.open_zarr(sorted_files[14],consolidated=True)

# %%
u6=xr.open_zarr(sorted_files[14],consolidated=True).u.isel(st_ocean=6)

# %%
u6

# %% [markdown]
# # load from `netcdf` and write to ...

# %%
xarray_open_kwargs = {"Time": 1, "st_ocean": 51, "xt_ocean": 3600, "yt_ocean": 1500}
ds = xr.open_mfdataset('/g/data/gb6/BRAN/BRAN2020/daily/ocean_'+var+'_*.nc',
                       parallel=True,chunks=xarray_open_kwargs,preprocess=keep_only_selected_vars)
ds

# %%
chunking_string = 'chunks_' + ''.join(str(key) + str(value)+ '.' for key, value in xarray_open_kwargs.items())
ard_rcTime_file_ID = 'BRAN2020-'+var+'-'+chunking_string+datestamp+'.zarr'

# %%
ard_rcTime_file_ID

# %%
# %%time
ds.to_zarr(BRAN2020_ard_path+ard_rcTime_file_ID,consolidated=True)

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/rechunk_done.log

# %% [markdown]
# # load the resulting float64 zarr and write to float32

# %%
ds_1_51_3600_1500_float64 = xr.open_zarr(BRAN2020_ard_path+ard_rcTime_file_ID,consolidated=True)

# %%
ds_1_51_3600_1500_float32 = ds_1_51_3600_1500_float64.copy(deep=True)

# %%
ds_1_51_3600_1500_float32['salt'] = ds_1_51_3600_1500_float64.salt.astype('float32')

# %%
ds_1_51_3600_1500_float32

# %%
# %%time
ds_1_51_3600_1500_float32.to_zarr(BRAN2020_ard_path+'float32.'+ard_rcTime_file_ID,consolidated=True)

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/float32_write_done.log

# %% [markdown]
# # load the float32 `ds_1_51_3600_1500`

# %%
ds_1_51_3600_1500_float32_reloaded = xr.open_zarr(BRAN2020_ard_path+'float32.BRAN2020-salt-chunks_Time1.st_ocean51.xt_ocean3600.yt_ocean1500.v08052024.zarr',
                                                  consolidated=True)
ds_1_51_3600_1500_float32_reloaded

# %%
ds_1_51_3600_1500_float32_reloaded

# %% [markdown]
# # chunking

# %%
chunking_1st_dict = {"Time": 11322, "st_ocean": 1, "xt_ocean": 30, "yt_ocean": 30}

# %%
chunking_string_1st = 'chunks_' + ''.join(str(key) + str(value)+ '.' for key, value in chunking_1st_dict.items())
ard_rc1_file_ID = 'BRAN2020-'+var+'-'+chunking_string_1st+datestamp+'.zarr'
ard_rc1_file_ID

# %%
ds_11322_1_30_30 = ds_1_51_3600_1500_float32_reloaded.copy(deep=True).chunk(chunking_1st_dict)
ds_11322_1_30_30

# %%
BRAN2020_ard_path+ard_rc1_file_ID

# %%
ds_11322_1_30_30 = remove_zarr_encoding(ds_11322_1_30_30)

# %%
# %%time
ds_11322_1_30_30.to_zarr(BRAN2020_ard_path+ard_rc1_file_ID,consolidated=True)

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/rechunk_11322_done.log

# %% [markdown]
# # netcdf to first zarr

# %%
xarray_open_kwargs = {"Time": 1, "st_ocean": 5, "xt_ocean": 3600, "yt_ocean": 1500}
ds = xr.open_mfdataset('/g/data/gb6/BRAN/BRAN2020/daily/ocean_salt_*.nc',parallel=True,chunks=xarray_open_kwargs,preprocess=keep_only_selected_vars)
ds

# %%
# %%time
ds.astype('float32').to_zarr(BRAN2020_ard_path+ard_file_ID,consolidated=True)

# %% [markdown]
# # load first zarr

# %%
ds_1_5_1500_3600 = xr.open_zarr(BRAN2020_ard_path+ard_file_ID,consolidated=True)

# %%
ds_1_5_1500_3600

# %%
chunking_dict={'Time':500,'xt_ocean':150}

# %%
ds_1_5_1500_3600.chunk(chunking_dict)

# %%
var='salt'

# %%
chunking_string = 'chunks_'+''.join(str(key) + str(value) for key, value in chunking_dict.items())
ard_rcTime_file_ID = 'BRAN2020-'+var+'-'+chunking_string+'-v07052024.zarr'

# %%
ds_1_5_1500_3600 = remove_zarr_encoding(ds_1_5_1500_3600)

# %%
from rechunker import rechunk
# !rm -rf /scratch/es60/ard/reanalysis/BRAN2020/ARD/temp_store/*
# Define target chunking
target_chunks = chunking_dict
target_store = BRAN2020_ard_path+ard_rcTime_file_ID
temp_store = BRAN2020_ard_path+'temp_store'  # Optional based on dataset size

# Execute rechunking
rechunk_plan = rechunk(ds_1_5_1500_3600, target_chunks, target_store=target_store, temp_store=temp_store,max_mem='8GB')

# %%
# %%time
rechunk_plan.execute()

# %%
# !touch /scratch/es60/ard/reanalysis/BRAN2020/ARD/rechunk_done.log

# %%
zarr.consolidate_metadata(target_store)
ds_all_1_150_150 = xr.open_zarr(target_store,consolidated=True)

# %%
ds_all_1_150_150
